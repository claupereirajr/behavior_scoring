# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import f

# %%
dfraw = pd.read_csv("dados_bancarios.csv", sep=";", index_col=0)
df = dfraw.copy()
df.head()
# Out:
#          Sexo  Idade  Empresa  Salario.decl Saldo.cc Saldo.poup Saldo.1ano  \
# Cliente
# 1           0     22        1          1000     72,5          0      54,73
# 2           0     40        1           500   130,06     371,12     138,71
# 3           0     39        2          2500   156,14          0     190,39
# 4           0     36        1          2500   112,02          0     115,04
# 5           0     28        1           500    69,07     152,83      47,43
#
#         Saldo.2anos  Tempo.relac  Limite.cartao  Dev.cartao  Inadimplente
# Cliente
# 1            130,02           80           2000           0             1
# 2            254,29           80           1000           0             0
# 3            384,94           80           5000           0             0
# 4            264,67           80           5000           0             0
# 5            163,78           80           1000        1059             1

# %%
corre = df.corr()
corre
# Out:
#                    Sexo     Idade   Empresa  Salario.decl  Tempo.relac  \
# Sexo           1.000000  0.002197 -0.005915     -0.004343     0.000486
# Idade          0.002197  1.000000  0.012532      0.186030     0.006730
# Empresa       -0.005915  0.012532  1.000000      0.009686    -0.009902
# Salario.decl  -0.004343  0.186030  0.009686      1.000000    -0.007776
# Tempo.relac    0.000486  0.006730 -0.009902     -0.007776     1.000000
# Limite.cartao -0.004343  0.186030  0.009686      1.000000    -0.007776
# Dev.cartao    -0.001042  0.054236  0.002244      0.274705     0.010825
# Inadimplente   0.095592 -0.005482 -0.000900     -0.013029     0.010424
#
#                Limite.cartao  Dev.cartao  Inadimplente
# Sexo               -0.004343   -0.001042      0.095592
# Idade               0.186030    0.054236     -0.005482
# Empresa             0.009686    0.002244     -0.000900
# Salario.decl        1.000000    0.274705     -0.013029
# ...

# %%
sns.heatmap(corre)
# Out:
# <AxesSubplot:>
